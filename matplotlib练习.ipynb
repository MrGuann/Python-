# %%
import matplotlib.pyplot as plt

# %%
list_year = [
    2006,
    2007,
    2008,
    2009,
    2010,
    2011,
    2012,
    2013,
    2014,
    2015,
    2016,
    2017    
]

list_gdp  = [
    219438.50,
    270232.30,
    319515.50,
    349081.40,
    413030.30,
    489300.60,
    540367.40,
    595244.40,
    643974.00,
    689052.10,
    744127.20,
    827122.00    
]

# %%
plt.bar(list_year,list_gdp)
plt.title("GDP amount from 2006 to 2017")
plt.xlabel('year')
plt.ylabel('GDP amount')
plt.show()

# %%
list_tradedate = [
    20180102,
    20180103,
    20180104,
    20180105,
    20180108,
    20180109,
    20180110,
    20180111,
    20180112,
    20180115,
    20180116,
    20180117,
    20180118,
    20180119,
    20180122,
    20180123,
    20180124,
    20180125,
    20180126,
    20180129,
    20180130,
    20180131,
    20180201,
    20180202,
    20180205,
    20180206,
    20180207,
    20180208,
    20180209,
    20180212,
    20180213,
    20180214,
    20180222,
    20180223,
    20180226,
    20180227,
    20180228
]

list_szzs = [
    3348.3259,
    3369.1084,
    3385.7102,
    3391.7501,
    3409.4795,
    3413.8996,
    3421.8343,
    3425.3449,
    3428.9407,
    3410.4882,
    3436.5940,
    3444.6713,
    3474.7540,
    3487.8640,
    3501.3622,
    3546.5048,
    3559.4653,
    3548.3070,
    3558.1288,
    3523.0007,
    3488.0090,
    3480.8334,
    3446.9799,
    3462.0808,
    3487.4970,
    3370.6520,
    3309.2598,
    3262.0504,
    3129.8508,
    3154.1254,
    3184.9587,
    3199.1589,
    3268.5589,
    3289.0241,
    3329.5737,
    3292.0679,
    3259.4080
]

# %%
import datetime
list_dt = []
for singleday in list_tradedate:
    dt_day = datetime.datetime.strptime(str(singleday),'%Y%m%d')
    list_dt.append(dt_day)

# %%
plt.figure(figsize=(18,9))
plt.plot(list_dt,list_szzs)
plt.title("shanghai stock exchange index")
plt.xlabel('date')
plt.ylabel('close_price')
plt.show()

# %%
gdp_2017 = {
    "primary industry"   : 65468,
    "secondary industry" : 334623,
    "tertiary industry"  : 427032
}
values = gdp_2017.values()
labels = gdp_2017.keys()

# %%
plt.figure(figsize = (6,6))
plt.pie(values, 
        labels=labels, 
        autopct='%.1f%%', 
        startangle= 90
    ) 
plt.axis('equal')
plt.legend()
plt.show()
